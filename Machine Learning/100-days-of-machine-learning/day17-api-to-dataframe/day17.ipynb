# %% [markdown]
# # Rapid api SITE to get free API
#
# https://rapidapi.com/categories

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File C:\Python310\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File C:\Python310\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# ...

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File C:\Python310\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File C:\Python310\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# ...

# %%
response.json()
# Out:
# {'data': {'artist': {'discography': {'albums': {'totalCount': 11,
#      'items': [{'releases': {'items': [{'id': '5aWF6mKr3bSRlMnyxA8Tip',
#           'uri': 'spotify:album:5aWF6mKr3bSRlMnyxA8Tip',
#           'name': 'Champagne Problems #DQH2',
#           'type': 'ALBUM',
#           'date': {'year': 2022, 'isoString': '2022-03-11T00:00:00Z'},
#           'coverArt': {'sources': [{'url': 'https://i.scdn.co/image/ab67616d00001e02fec9341c25339773dfe59cb5',
#              'width': 300,
#              'height': 300},
#             {'url': 'https://i.scdn.co/image/ab67616d00004851fec9341c25339773dfe59cb5',
#              'width': 64,
#              'height': 64},
#             {'url': 'https://i.scdn.co/image/ab67616d0000b273fec9341c25339773dfe59cb5',
#              'width': 640,
#              'height': 640}]},
#           'playability': {'playable': True, 'reason': 'PLAYABLE'},
#           'sharingInfo': {'shareId': 'TCCmFqz6SmuWCX7cK7vGKg',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path            genre_ids      id  \
# 0   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg             [18, 80]     278
# 1   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg      [35, 18, 10749]   19404
# 2   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg             [18, 80]     238
# 3   False  /loRmRzQXZeqG78TqZuyvSlEQfZb.jpg      [18, 36, 10752]     424
# 4   False  /poec6RqOKY9iSiIUmfyfPfiLtvB.jpg             [18, 80]     240
# 5   False  /bxSBOAD8AuMHYMdW3jso9npAkgt.jpg          [10751, 18]  667257
# 6   False  /3RMLbSEXOn1CzLoNT7xFeLfdxhq.jpg          [10749, 16]  372754
# 7   False  /hZth9NCeXvvO7Xi98d8q34e1Ier.jpg      [16, 10751, 14]     129
# 8   False  /mMtUybQ6hL24FXo0F3Z4j2KG7kZ.jpg      [10749, 16, 18]  372058
# 9   False  /w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg              [10749]  696374
# 10  False  /tj6iPnz18hGfr0LKqWmG6Cp3niO.jpg                 [18]     389
# 11  False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg         [35, 53, 18]  496243
# ...

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#        id                        title  \
# 0   19404  Dilwale Dulhania Le Jayenge
# 1  724089    Gabriel's Inferno Part II
# 2     278     The Shawshank Redemption
# 3     238                The Godfather
# 4  761053   Gabriel's Inferno Part III
#
#                                             overview release_date  popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      18.433
# 1  Professor Gabriel Emerson finally learns the t...   2020-07-31       8.439
# 2  Framed in the 1940s for the double murder of h...   1994-09-23      65.570
# 3  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      63.277
# 4  The final part of the film adaption of the ero...   2020-11-19      26.691
#
#    vote_average  vote_count
# 0           8.7        2763
# 1           8.7        1223
# 2           8.7       18637
# 3           8.7       14052
# 4           8.7         773

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#           id                        title  \
# 0      19404  Dilwale Dulhania Le Jayenge
# 1     724089    Gabriel's Inferno Part II
# 2        278     The Shawshank Redemption
# 3        238                The Godfather
# 4     761053   Gabriel's Inferno Part III
# ...      ...                          ...
# 8546   13805               Disaster Movie
# 8547    5491            Battlefield Earth
# 8548   14164         Dragonball Evolution
# 8549   11059            House of the Dead
# 8550   40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1     Professor Gabriel Emerson finally learns the t...   2020-07-31
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# 3     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 4     The final part of the film adaption of the ero...   2020-11-19
# ...

# %%
df.shape
# Out:
# (8551, 7)

# %%
df.to_csv('movies.csv')

# %% [markdown]
# # Spotify dataset Using rapidapi

# %%
import requests

url = "https://spotify23.p.rapidapi.com/playlist/"

querystring = {"id":"37i9dQZF1DX4Wsb4d7NKfP"}

headers = {"X-RapidAPI-Key": "501008c206mshcc857884836f45bp198f83jsne6c638c27097",
           "X-RapidAPI-Host": "spotify23.p.rapidapi.com"}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}

# %%
import requests

url = "https://spotify23.p.rapidapi.com/albums/"

querystring = {"ids":"3IBcauSj5M2A6lTeffJzdv"}

headers = {"X-RapidAPI-Key": "501008c206mshcc857884836f45bp198f83jsne6c638c27097",
           "X-RapidAPI-Host": "spotify23.p.rapidapi.com"}

response = requests.request("GET", url, headers=headers, params=querystring)

response.json()['albums']
# Out:
# [{'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/51DevdOxIJin6DB1FXJpD1'},
#     'id': '51DevdOxIJin6DB1FXJpD1',
#     'name': 'UZI',
#     'type': 'artist',
#     'uri': 'spotify:artist:51DevdOxIJin6DB1FXJpD1'}],
#   'copyrights': [{'text': '2021 M.O.B Entertainment Associated Label Of Govinet',
#     'type': 'C'},
#    {'text': '2021 M.O.B Entertainment Associated Label Of Govinet',
#     'type': 'P'}],
#   'external_ids': {'upc': '3616553578384'},
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3IBcauSj5M2A6lTeffJzdv'},
#   'genres': [],
#   'id': '3IBcauSj5M2A6lTeffJzdv',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27367c738a703dc979f5c3c52ef',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0267c738a703dc979f5c3c52ef',
#     'width': 300},
#    {'height': 64,
# ...

# %%
df2.head().T
# Out:
#                                                                         0
# album_type                                                          album
# artists                 [{'external_urls': {'spotify': 'https://open.s...
# copyrights              [{'text': '2021 M.O.B Entertainment Associated...
# external_ids                                     {'upc': '3616553578384'}
# external_urls           {'spotify': 'https://open.spotify.com/album/3I...
# genres                                                                 []
# id                                                 3IBcauSj5M2A6lTeffJzdv
# images                  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# label                                                M.O.B. Entertainment
# name                                                                  Kan
# popularity                                                             65
# release_date                                                   2021-03-19
# ...

# %%
import requests

url = "https://spotify23.p.rapidapi.com/album_metadata/"

querystring = {"id":"3IBcauSj5M2A6lTeffJzdv"}

headers = {"X-RapidAPI-Key": "501008c206mshcc857884836f45bp198f83jsne6c638c27097","X-RapidAPI-Host": "spotify23.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

response.text
# Out:
# '{"data":{"album":{"uri":"spotify:album:3IBcauSj5M2A6lTeffJzdv","name":"Kan","artists":{"totalCount":1,"items":[{"uri":"spotify:artist:51DevdOxIJin6DB1FXJpD1","profile":{"name":"UZI"},"visuals":{"avatarImage":{"sources":[{"url":"https:\\/\\/i.scdn.co\\/image\\/ab6761610000e5eb8a2705cb98493cc305b0fde9","width":640,"height":640},{"url":"https:\\/\\/i.scdn.co\\/image\\/ab6761610000f1788a2705cb98493cc305b0fde9","width":160,"height":160}]}},"sharingInfo":{"shareUrl":"https:\\/\\/open.spotify.com\\/artist\\/51DevdOxIJin6DB1FXJpD1?si=PdKKPfKWRJmGty0ZCxCXHw"}}]},"coverArt":{"extractedColors":{"colorRaw":{"hex":"#404040"}},"sources":[{"url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d00001e0267c738a703dc979f5c3c52ef","width":300,"height":300},{"url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d0000485167c738a703dc979f5c3c52ef","width":64,"height":64},{"url":"https:\\/\\/i.scdn.co\\/image\\/ab67616d0000b27367c738a703dc979f5c3c52ef","width":640,"height":640}]},"discs":{"totalCount":1,"items":[{"number
# ...

# %%
import requests

url = "https://spotify23.p.rapidapi.com/album_tracks/"

querystring = {"id":"3IBcauSj5M2A6lTeffJzdv","offset":"0","limit":"300"}

headers = {"X-RapidAPI-Key": "501008c206mshcc857884836f45bp198f83jsne6c638c27097","X-RapidAPI-Host": "spotify23.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

response.json()
# Out:
# {'data': {'album': {'playability': {'playable': True},
#    'tracks': {'totalCount': 10,
#     'items': [{'uid': '3d026f76adb5928f0e59',
#       'track': {'saved': False,
#        'uri': 'spotify:track:5jvhTc0g18kwYQNUJM5C4e',
#        'name': 'Makina',
#        'playcount': '76804170',
#        'discNumber': 1,
#        'trackNumber': 1,
#        'contentRating': {'label': 'EXPLICIT'},
#        'relinkingInformation': None,
#        'duration': {'totalMilliseconds': 211016},
#        'playability': {'playable': True},
#        'artists': {'items': [{'uri': 'spotify:artist:51DevdOxIJin6DB1FXJpD1',
#           'profile': {'name': 'UZI'}}]}}},
#      {'uid': '419656ce995b7d2148d1',
#       'track': {'saved': False,
#        'uri': 'spotify:track:72t3CRd8YEFrlc3x0OVaob',
#        'name': 'Umrumda Değil',
#        'playcount': '87697821',
#        'discNumber': 1,
#        'trackNumber': 2,
#        'contentRating': {'label': 'EXPLICIT'},
#        'relinkingInformation': None,
# ...

# %%
import requests

url = "https://spotify23.p.rapidapi.com/artist_albums/"

querystring = {"id":"2w9zwq3AktTeYYMuhMjju8","offset":"0","limit":"100"}

headers = {"X-RapidAPI-Key": "501008c206mshcc857884836f45bp198f83jsne6c638c27097","X-RapidAPI-Host": "spotify23.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

data = response.json()['data']

# %%
data
# Out:
# {'artist': {'discography': {'albums': {'totalCount': 11,
#     'items': [{'releases': {'items': [{'id': '5aWF6mKr3bSRlMnyxA8Tip',
#          'uri': 'spotify:album:5aWF6mKr3bSRlMnyxA8Tip',
#          'name': 'Champagne Problems #DQH2',
#          'type': 'ALBUM',
#          'date': {'year': 2022, 'isoString': '2022-03-11T00:00:00Z'},
#          'coverArt': {'sources': [{'url': 'https://i.scdn.co/image/ab67616d00001e02fec9341c25339773dfe59cb5',
#             'width': 300,
#             'height': 300},
#            {'url': 'https://i.scdn.co/image/ab67616d00004851fec9341c25339773dfe59cb5',
#             'width': 64,
#             'height': 64},
#            {'url': 'https://i.scdn.co/image/ab67616d0000b273fec9341c25339773dfe59cb5',
#             'width': 640,
#             'height': 640}]},
#          'playability': {'playable': True, 'reason': 'PLAYABLE'},
#          'sharingInfo': {'shareId': 'TCCmFqz6SmuWCX7cK7vGKg',
# ...

# %%
data['artist']['discography']
# Out:
# {'albums': {'totalCount': 11,
#   'items': [{'releases': {'items': [{'id': '5aWF6mKr3bSRlMnyxA8Tip',
#        'uri': 'spotify:album:5aWF6mKr3bSRlMnyxA8Tip',
#        'name': 'Champagne Problems #DQH2',
#        'type': 'ALBUM',
#        'date': {'year': 2022, 'isoString': '2022-03-11T00:00:00Z'},
#        'coverArt': {'sources': [{'url': 'https://i.scdn.co/image/ab67616d00001e02fec9341c25339773dfe59cb5',
#           'width': 300,
#           'height': 300},
#          {'url': 'https://i.scdn.co/image/ab67616d00004851fec9341c25339773dfe59cb5',
#           'width': 64,
#           'height': 64},
#          {'url': 'https://i.scdn.co/image/ab67616d0000b273fec9341c25339773dfe59cb5',
#           'width': 640,
#           'height': 640}]},
#        'playability': {'playable': True, 'reason': 'PLAYABLE'},
#        'sharingInfo': {'shareId': 'TCCmFqz6SmuWCX7cK7vGKg',
#         'shareUrl': 'https://open.spotify.com/album/5aWF6mKr3bSRlMnyxA8Tip?si=TCCmFqz6SmuWCX7cK7vGKg'},
# ...
